# %%
const Grammar = Vector{Tuple{String, String}}

function generate_word(grammar::Grammar, start_symbol::String="S", max_depth::Int=15)
    if max_depth <= 0 return "" end
    rules = [rhs for (lhs, rhs) in grammar if lhs == start_symbol]
    if isempty(rules) return start_symbol end

    chosen_rhs = rand(rules)
    word = ""
    for char in chosen_rhs
        token = string(char)
        if isuppercase(char)
            sub = generate_word(grammar, token, max_depth - 1)
            if sub == "" && max_depth < 5 return "" end
            word *= sub
        else
            word *= token
        end
    end
    return word
end

global var_counter = 0
function get_new_var() global var_counter += 1; return "_X$var_counter" end

function to_cnf(input_grammar::Grammar)
    global var_counter = 0
    step1 = Grammar()
    term_map = Dict{Char, String}()
    function get_term(c)
        if haskey(term_map, c) return term_map[c] end
        v = get_new_var(); push!(step1, (v, string(c))); term_map[c] = v; return v
    end

    for (lhs, rhs) in input_grammar
        if length(rhs) == 1 && islowercase(rhs[1]) push!(step1, (lhs, rhs)); continue end
        toks = []
        for c in rhs
            push!(toks, islowercase(c) ? get_term(c) : string(c))
        end
        if length(toks) == 1 push!(step1, (lhs, toks[1]))
        else
            curr = lhs
            while length(toks) > 2
                f = popfirst!(toks); nv = get_new_var()
                push!(step1, (curr, f * nv)); curr = nv
            end
            push!(step1, (curr, toks[1] * toks[2]))
        end
    end

    unit_pairs = Set{Tuple{String, String}}()
    non_unit = Grammar()
    for (l, r) in step1
        is_u = (length(r)==1 && !islowercase(r[1])) || (startswith(r, "_") && !occursin(r"(_X\d+).+", r) && length(r) < 5)
        if is_u push!(unit_pairs, (l, r)) else push!(non_unit, (l, r)) end
    end

    changed = true
    while changed
        changed = false
        curr = collect(unit_pairs)
        for (a, b) in curr, (c, d) in curr
            if b == c && !((a, d) in unit_pairs) && a != d
                push!(unit_pairs, (a, d)); changed = true
            end
        end
    end

    final = copy(non_unit)
    for (p, child) in unit_pairs
        for (l, r) in non_unit
            if l == child push!(final, (p, r)) end
        end
    end
    return unique(final)
end

function cyk_parse(w::String, grammar::Grammar, start_symbol::String="S")
    n = length(w)
    if n == 0 return false end
    inv = Dict{String, Set{String}}()
    for (l, r) in grammar
        if !haskey(inv, r) inv[r] = Set{String}() end
        push!(inv[r], l)
    end
    T = [Set{String}() for _ in 1:n, _ in 1:n]
    for i in 1:n
        s = string(w[i])
        if haskey(inv, s) union!(T[i, 1], inv[s]) end
    end
    for l in 2:n, i in 1:(n-l+1), k in 1:(l-1)
        left, right = T[i, k], T[i+k, l-k]
        if isempty(left) || isempty(right) continue end
        for B in left, C in right
            rhs = B * C
            if haskey(inv, rhs) union!(T[i, l], inv[rhs]) end
        end
    end
    return start_symbol in T[1, n]
end

g1 = [
    ("Z", "A"), ("A", "ab"), ("A", "aBa"), ("A", "CDD"),
    ("B", "ab"), ("B", "aBa"), ("B", "DDD"),
    ("C", "ba"), ("C", "bDb"), ("C", "AB"),
    ("D", "ba"), ("D", "bDb"), ("D", "BB")
]

g2 = [
    ("Z", "A"), ("A", "ab"), ("A", "aBa"), ("A", "EHH"),
    ("B", "ab"), ("B", "aBa"), ("B", "FHH"),
    ("C", "ab"), ("C", "aDa"), ("C", "GHH"),
    ("D", "ab"), ("D", "aDa"), ("D", "HHH"),
    ("E", "ba"), ("E", "bGb"), ("E", "AD"),
    ("F", "ba"), ("F", "bHb"), ("F", "BD"),
    ("G", "ba"), ("G", "bGb"), ("G", "CD"),
    ("H", "ba"), ("H", "bHb"), ("H", "DD")
]

g3 = [
    ("S", "TTT"), ("S", "aSa"), ("S", "ab"),
    ("T", "SS"), ("T", "bTb"), ("T", "ba")
]

function compare_grammars(count=5)
    pairs = [
        ("G1", g1, "Z", "G2", g2, "Z"),
        ("G1", g1, "Z", "G3", g3, "S"),
        ("G2", g2, "Z", "G3", g3, "S")
    ]

    for (name1, g1_raw, s1, name2, g2_raw, s2) in pairs
        println("Сравнение: $name1 vs $name2")

        cnf1 = to_cnf(g1_raw)
        cnf2 = to_cnf(g2_raw)

        function run_direction(src_name, src_g, src_s, target_name)
            println("Источник: $src_name")

            match_count = 0
            valid_gen = 0

            for i in 1:count
                w = ""
                attempts = 0
                while w == "" && attempts < 20
                    w = generate_word(src_g, src_s, 14)
                    attempts += 1
                end
                if w == "" continue end
                valid_gen += 1

                res1 = cyk_parse(w, cnf1, s1)
                res2 = cyk_parse(w, cnf2, s2)
                match = (res1 == res2)

                println(rpad(w, 35), " | ", res1, " | ", res2, " | ", match)

                if res1 == res2 match_count += 1 end
            end
            if valid_gen > 0
                println("Совпадений: $match_count из $valid_gen")
            end
        end

        run_direction(name1, g1_raw, s1, name2)
        run_direction(name2, g2_raw, s2, name1)
    end
end

compare_grammars(50)
# Out:
# Сравнение: G1 vs G2
# Источник: G1
# aaba                                | true | true | true
# aaba                                | true | true | true
# aabbbabbbaaaabaaaababbabbabbabaaabaaaa | true | true | true
# aaba                                | true | true | true
# bbabbabaaabbbabbbababbaaaabb        | false | false | true
# bbabbabaaababbbabbbbabaababbabaaabaaabbabbabaaaabaaaaaaabababbabbbbaabaaaabaabaababababbababbabbbabb | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# baabaababbbbabbbabababbbbbbabbbaabaaabaaabaabaabbbabaaabaabababaaabaaaaaaabaaaabaabaabaaaaaaaabaabbaaababbbbabbbbaaabaaabbabaabaabaabbbbbbab | false | false | true
# ababaabaaabaabbabbabbababaababaabbbbbabbabaaabaaaaba | true | true | true
# ababbabaababbabbabbabababaabbabbaabaabaaabaaaaaaaabaaaabaabaabaaabaabbabbabbbababbabbaabbabbabbabbbabbabababbababbaaabaaaabababababaabbabaaabaabbb | true | true | true
# ab                                  | true | true | true
# aabababaabaabaabbbbabbbabaabababaababa | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# aaabaabbbabbababaabbababbabbaabbbabbbbabbbabbababbbbababba | true | true | true
# aabaabaabababbaababbbabbaaaaabaaaababaababbbbbbabbbbababbbababaababaaabaaaaababbbabbbaaababbabaababbbbabbabbaabaabbbbbababbaaabaababababaababbbaabababbabbabbabababbababbb | true | true | true
# bbabaaabaabbbaaababababbbabbbabababaaaabaabaabaaababaaaabbabbababbbbbbbbabbbbbbbab | true | true | true
# aaaaabaaaaabbbabbababbababbbabbbbabaabbbbaaabaabbbbbbbabbabaabbababaaababbabababababbaabbaaaaabaaaabbbaa | false | false | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ababaabbabaaaabaaaabaaaabaabbbbabbbabbbaba | false | false | true
# ab                                  | true | true | true
# aaaaabaaabbabbababaababaaabababaabaaaa | true | true | true
# abaabbabbabbbababaabaaaabababa      | true | true | true
# babbabababababaaababbabbabababaaaaabaaaaabaaabbabbbbbbbbbabbbbbabbabbbabbababbababbabbababbabbabbbababbabbbabaaabaabaababaaabababbabbbbabbaabaaabaaabbbbabbbaababbabbaaaaabbababaaaaabaaaaababbbaabaabbbbbaaba | true | true | true
# ab                                  | true | true | true
# ababbabababbabbabaababaaabaabbbabbaaaabbabbbabaabababababbbbbabbbaababaaabaabbaababbaa | true | true | true
# aaba                                | true | true | true
# abaaabaabbaa                        | true | true | true
# babbabba                            | true | true | true
# babbbabbabbbabbabababbbabaabbabbabaababbbbabbaaaabaabbbababbbababbbaaabaaabbbababbbabbbabaabbabbab | true | true | true
# aabbabbbbabbbbbabbaa                | true | true | true
# aaba                                | true | true | true
# baaabaabbbbabbbaaabaaaabaaab        | true | true | true
# ab                                  | true | true | true
# aababaabbabababbaabaababbbabaa      | true | true | true
# ab                                  | true | true | true
# babbbabbba                          | true | true | true
# bbbabbbaabababaabbbabbabbabbababba  | false | false | true
# bababa                              | true | true | true
# aaaabaaa                            | true | true | true
# ab                                  | true | true | true
# Совпадений: 50 из 50
# Источник: G2
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# abbaababbababbababbbbabbbbbbbbabbbbbbabababbabbaababbabbbbaaabaaaabbabbabbaababbbaababbbbabbaababababbbbabbbabbbbabbbaabaabaabaa | true | true | true
# ab                                  | true | true | true
# aaaaabaaaa                          | true | true | true
# abbabaabaaaabaaababaaabaabaaabababaabaaaaabaaaabbbbabbaa | true | true | true
# ab                                  | true | true | true
# bababaabaabbaabaabaabbbbbabbbbabba  | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# abababaa                            | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ababaababbaababaababbabbabbaaaabaaababaababbaaabaaababbbbabbbabaaabaababbbabbbaaababababaaababbababbabbababbaabaaabaababaabababa | true | true | true
# baabaabbbaaaabaabababaababbababaabbabababaaaaabaab | false | false | true
# baabaabbbbbbbbbbbbbbabbbaabababbabbbabbababababbbabbabbbabbaaaaaabbbababbbabbabaababbbabbbababbbbabbbaabaabbbbbbabbbbbababbabbbaabbaabaababababbbbababbbab | false | false | true
# aabbabbabaaabbabbbabbabbababababbabbbbabbbabaababa | true | true | true
# ab                                  | true | true | true
# abbabbabaababaababaabbabbbbabbbbabbbababbababbbababa | true | true | true
# ababbbabba                          | true | true | true
# bbbabbbaaaabaaaaaabaaaaababbbababaabababbabaabababbbaabaabbbaaabbabbba | true | true | true
# aaaaabaaaa                          | true | true | true
# aaaaabaaaaababaabaababbbabbbbabbbbbabbaaabaabaabababaabababbbbbabaababbbbabbaabbbaaabaabaaaaababaaaabaaabbbbbaaabaababaaababbabaaabaabbaabab | false | false | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# aaba                                | true | true | true
# aababababababbbabaaaababbababbababbababbbabbbaababaa | true | true | true
# aababababbbabaaaabbababaabbabababbbabbbabaabababbabbababbabbaa | false | false | true
# aabaababaababa                      | true | true | true
# babbabbabbbabaababaaababbaabaaabaabaaabaabbbaabababbbaab | false | false | true
# bbbabbaaaaabaaaaabbbababbb          | true | true | true
# aaba                                | true | true | true
# bababbababbababbbbbabbbaaabaaaababaaaabaabbababbbabbbbbaabbaba | true | true | true
# ab                                  | true | true | true
# babbabaaabaaab                      | true | true | true
# ab                                  | true | true | true
# abbbbbbbbbbbbbaaabaaabaabababbaabaababababbbabbbabaababaababbabbbabaababbabbbbaaababaababbabbbabaabababbabbbbabababbabbbbbaabaaabaababababaaaaabaaabaaba | false | false | true
# bbbbabbbbbabaababababbababbb        | true | true | true
# babaaababaababbaaaabaaabbabbbabb    | false | false | true
# abbaabbbabbabbbabbbabbabbababababa  | false | false | true
# aaba                                | true | true | true
# abaaaabaaabaaaaabaaaaaabaa          | true | true | true
# ab                                  | true | true | true
# babaaaabaaabbabbbabb                | true | true | true
# ab                                  | true | true | true
# Совпадений: 50 из 50
# Сравнение: G1 vs G3
# Источник: G1
# aaba                                | true | true | true
# bababbbbbabbababaaabbbaaaabaaabaabbaab | false | false | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# aaabaa                              | true | true | true
# ab                                  | true | true | true
# bababa                              | true | true | true
# abbbababbabaabbbabbbbaabbbababaabaaababaababaabbbbabbbaababbababaababbabaabababaabababaabababbab | false | false | true
# babababbaabaab                      | true | true | true
# baababbabbaabaaababaababaabbaababaaaabaaaaababababbabbabbababbbbbbbabbbbbbabbababababbaabababbbabbabbabababaaabaabababab | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# aabababaaa                          | true | true | true
# ab                                  | true | true | true
# aaabababaaabaaaaaabaaaaaaabaaababbaabaaaabaaaababbababaabbbabbbbaabaaa | false | false | true
# aaabaabbababbabababbabbabaabaaababbabbabbbabaabbbbabbaabababaaaabbbbabbabbbbabbbabababaabababbabbbabbaba | true | true | true
# babababbbbbabbbbbaaabbabbbbabbbbbbababbabaababaa | false | false | true
# aaabaa                              | true | true | true
# aababbbabbbbbabbaaabaabababbbbabaababbababaabababbababababaaabaabaaaabababaa | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# aaabaaabbaaaaabbabbbbbabbbbbbbbabaababaabaaabbababbababbbaababbaaabaababbbaabaabbabaababababababbababbabaabbabbabaabbabababbaaaa | false | false | true
# aabaaaaababbabaabaabbabbababbbbaaabbababbbbabbbaabbbbabbbbbababbbbaababaaabbababaabaabaabaaababbbbbabbbaabaabbabba | false | false | true
# aaabababaaaa                        | true | true | true
# baabaabbabbbbbbabbbabbabbababbabaabbababbbababbbbababaabaabababaaaabababbababb | false | false | true
# abbbabbbbbbaaabaaabbbbbaabaabbbbbbbbbababbababaa | false | false | true
# ab                                  | true | true | true
# abababaababbab                      | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# aaabaa                              | true | true | true
# aaabaa                              | true | true | true
# bababbab                            | true | true | true
# aababbabbabbababbabaaabaababbabbabaababaaaabaaabbabaabaaabababaabaaababbabbbabbbabbbabbaaabbbabbbbabaaaaababababababbbabaaaabaabbabbbabbabbbabbbbbabbbbabbbbabaabaabababbaaaaababaabba | true | true | true
# aaabaa                              | true | true | true
# babbbabbbbababbbbbababababbbaaabbbababbbaaabbabbababababababbbabbbababababaababbabababbbbabbbbbabbabba | true | true | true
# aaba                                | true | true | true
# aaaabbabbbabbaaaaabbabbaba          | true | true | true
# babbbbabbbbaababbbbabbbabbababababaabaaabaaaababababbabababababbabbbabbababaabaababababbbbabbbbbabbabbbbbabbbbbabbababababababbababbabba | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# abbbbaababbbbbbabbababbabbbbabbbaababbaababbbabbaa | false | false | true
# ab                                  | true | true | true
# abbabbbbabbbaa                      | true | true | true
# Совпадений: 50 из 50
# Источник: G3
# abababbaba                          | true | true | true
# abaaabababababbbaaabaaabbbabbbbbabbbbaabbbabaaababbbbbabbbbbaa | true | true | true
# abaaabaaabaaababbbababaabbbbbabbabaabababbabaabababbbbababaababbabbbabaaababbbaaabaabbabbaaababaababbaabaaaabaabaabbbbabbbaabaabbbaaabaa | true | true | true
# aababbbbabbabbabbbababaaababbababbabaabababbabaaabaaaaabaaabbabaababaa | true | true | true
# bababbab                            | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
#  | false | false | true
# ab                                  | true | true | true
# bbabbabbabbababbabaaabbabbbabbbbbabbbabaabaaabaabbaaabaabbaabbbbabba | true | true | true
# baaabaabbbbbbabbbbbababbbbbabaabbbbabbabbbbabbbababbbbabaaaabaaaabbaabababaababaabaabababababbabaabbabaababbbabaaa | true | true | true
# bbabbbaababbabaabbbbabababbbaabababbabaaabaabababbabaabbbbabbabababbabaababaababbabbbbababbbbbabbbabbbabbabbaababbbaabab | true | true | true
# bababa                              | true | true | true
# aabbbbbbbabbbbbbbabbabbaaabaaababbbaabbbabbaabaabbbaababbbbbbabbbababbbabaaabaaaabaaabababbbbababbabaaaaaabaababbabbbabbabaaabaaabaaababbabababbaaabbbabaabaabbaababbaabbabbaabababbabbbbabbaaabaabaabbbabbbaa | true | true | true
# ab                                  | true | true | true
# babaabbbabbaaaaaaabbaabaaaabaaabbabbbaababbababababaababaaaabaaa | false | false | true
# babbabaabaabababaabbbbbaabbbbbbaabababbbabbbbabaabaaabaabaababbbabbbbaaaaaabaaaababbab | false | false | true
# ababbabaabaababaabaabaaa            | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# abaabaabbaaaabaabbabbabbabababbbababbabbbabbbabbabaaaabbaabbbbbabbba | false | false | true
# ab                                  | true | true | true
# babbbabbabababbbabbaabaabb          | true | true | true
# aaabababaaaa                        | true | true | true
# aaabaa                              | true | true | true
# bbababbabaaababababbabababbbabaababbbbabbabababbabaaaabaaababbbbbbabbbaababababbbaaaaabaaaabaabbbabbaaba | true | true | true
# ab                                  | true | true | true
# ababaabbabaababbaabbbabbbababbbaaababbabababaabbbabbabbaaaaabbabbabaaaaababbabbaababababbbababbabaababababbbbbabaaabaababa | true | true | true
# ab                                  | true | true | true
# abaaabaabbbbbabbba                  | true | true | true
# abababaa                            | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ababbbabbbbbbabbbaabbbbbabaababababbbaabababaaaabaaaabababbabbaabababbbabaabaababbbabb | false | false | true
# baabaaababababababbabbbbbbaaabbababbaaabaaaaabaabbbbabababababbabbabbbaaabababbababbbbabbababbbaaabaabbabababbabababaabaababbabbbababbbababa | true | true | true
# ab                                  | true | true | true
# aaba                                | true | true | true
# bbbbabbbbbabbbbabb                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# aaba                                | true | true | true
# babbbabbabaaabbabbababbbabaabaaa    | false | false | true
# baaaaabaaaaaabaaaabaabaaaaababababbbbabbaabababaaaabbbbbabbbabaababababbbbbbbabbbabbbabbbbabbabbabaabaababbababaabbbba | false | false | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# Совпадений: 50 из 50
# Сравнение: G2 vs G3
# Источник: G2
# ab                                  | true | true | true
# ab                                  | true | true | true
# aaababaababaaa                      | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# babbabbababbbabbabaaababbbabbaababbbabaaaaaabaabababaaabaaaabaaabbbabbaababbbbabbbab | true | true | true
# aaabababbbababaabaababaaabbaaabaababbababbbbaabbbabbbaaa | true | true | true
# aaaaabaaaaaaabaababa                | true | true | true
# baaaaaabaaaaabba                    | true | true | true
# abbabbbbabaababbbbaabaaaabbababbabaaabbabbabbbababbabbabbbbabbbaabbbaa | false | false | true
# ab                                  | true | true | true
# aabaabbbbbbabbbabbabaaababbababbbbaababbabbabbabaaaabaabbbabbaabaabaababababbabbbabbbbabbabaabbabbabbbabaaaaabaabaaababababbabaaaaaabababbaaaabbababababbaaabbbabbbababaaabbbbabbbbbabbbbbbabbbaabaababababbabababaaaaaabbba | false | false | true
# ab                                  | true | true | true
# ababbaba                            | true | true | true
# abababbabbbabbbaabababaaababbaabababbbabaabbaaababbabbaababaaaaabababababaabbababa | false | false | true
# aaba                                | true | true | true
# babaaaabaaabaaabababaabaabaaabbabbaaaaba | false | false | true
# aaaababbbabbbaaaaa                  | true | true | true
# ab                                  | true | true | true
# bbabbbbabbbabbbaabaaabababbabaabbabbbaaababbabaabbabaababaaaabaaaaabaababbba | false | false | true
# aabababbbbbabbbaaa                  | true | true | true
# aaba                                | true | true | true
# abababaa                            | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# baababbbab                          | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ababaaabaabaabbabaababaabaaabaaababbabbaabbbababbbabbbabbaba | true | true | true
# bababa                              | true | true | true
# ab                                  | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# babababbbabbabbaababbbbabbaaabaa    | true | true | true
# aaaabaaa                            | true | true | true
# aaba                                | true | true | true
# bbbabbbabababababbbabbbbababaaabaabbbbaabbbabbbabbbaabaabbabbbabbbbbaababbbabbabbababbabababbabbbabbbababaaaabaabbababaababbbabbbbaabababaaaabaababbbbbabaabbababbbabbaabaaabaaaabaabbabababbaababaabaaaabaaaababbabbabababa | true | true | true
# babaabbabbabbbab                    | true | true | true
# ab                                  | true | true | true
# aaababbbbabbbaaa                    | true | true | true
# bababa                              | true | true | true
# abbbabbaaaabababaaaaaabbabbbbabbbbabbabbaabaabbabaabaabbaabaababaabaabbababaaabaababababbbbabbabbabbabbbaabbbabbabaa | true | true | true
# ab                                  | true | true | true
# aaaabaaaaaabbabbabaababbbaaaaaabababbababbaabababbbbababababbbbaababbbabaababababbbabbbabaabababababbabababbbabbbbbabbbb | false | false | true
# ababbabaababaaabaabababbbabbbbabaababbababaabbabbabababbaaaabbababbbabbaaaabaabbababbabaabaabbaabbbabbbabbbaabbababaaabaabaababbabbaabaabaaabaabbbaabaaabaaaabaaababaaaaabaabbbaabaabbbbabaaaaabaaaaaabaabbbabbbabaaabaabb | true | true | true
# aaba                                | true | true | true
# aabbabaaabaaabbababbaabaaababaabbababbabababbabbbbabaaababbaababbabbabababbabbbabbababbbabaabaaaabaabababbaaabbbababbaba | true | true | true
# Совпадений: 50 из 50
# Источник: G3
# aaba                                | true | true | true
# ab                                  | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# aaabaaabbabbabbabbbabbbbbabbbaaaabbabbababaaabbbabbbabaaaaaaaaabbabbabaabbaaaaabaaaaaababb | false | false | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# aaba                                | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# abaabaaaaaabaaaaaabaababbbbbbababbabaaababaababa | false | false | true
# bababa                              | true | true | true
# bbbababbbaabbabaaabaabbabababababaababbbabaababbbababaababbaaaaaaaabbababbabaaabababbabbabaaababaaabaabaabababbbbabbaaabbbab | false | false | true
# aababbbabbbbaabababbbabababbabbbbbabbbbabaababbababbaa | true | true | true
# aaba                                | true | true | true
# ababbaba                            | true | true | true
# ab                                  | true | true | true
# abbababbbabbabbbababbbababaabbbbbabbbabaabaaabbabaababababbbabbbabbabaabbbbabbbbbbabbbbababababbbabaababbabaab | true | true | true
# ab                                  | true | true | true
# ab                                  | true | true | true
# aaababaabbabbbabbabaaababbabaabbaababbabaaaabaaabaabaabaaaaaabbababbbaaaabbabbaabaabbaaabaaababaabaababaabbabbabaabaabbabbababbaabbbabbababababaabbaabaabbbbaabaaaaabaaabbabababbabaabbbaaaabaabaa | false | false | true
# abbaabaabaababbaaabaabbbbabbababaabaaaabaaabbbbbbbabbabaabaababbabababbbabbaabababbbaaaabaaabaabbbbbbaaabbbbbbaabaabbabaababaaabaaabaaabaaabbabbabaaaabaababbbababbbbbbaababbabbbababbbaabbbbbbbbbbaabbabbbbbbbbbababaaaaaaabaaaabaabbbbbbbbabaaaaab | false | false | true
# baaaabaaaabaabbbabbaaabaabababababbababaababbabaababaabaaabaabbbabbababababbbabbabaaabababaababaaabaaaabaabbab | true | true | true
# bbbabbbaba                          | true | true | true
# ab                                  | true | true | true
# abbabababaaaababbbbabbaa            | true | true | true
# bababbbabb                          | true | true | true
# aaabbbabaabaaababbabbbabbbabaa      | true | true | true
# ababbbaabaababbbbbbbbbbabbabbababa  | false | false | true
# abbabbababaaabaabbbbabbaaabaabababbbabbbbabbabababababbabaaaabababababababbabbaa | true | true | true
# ab                                  | true | true | true
# aaba                                | true | true | true
# aaabaa                              | true | true | true
# baababababbabaaaaaabaaaaabbabbbabbabaaabaaaabaabbabbababaaababaaaaabaa | true | true | true
# ab                                  | true | true | true
# baabababbaabbabaabbababaabbabaaabbababaaaabaabaaaaaababbbbabbbabababaabbbabbbbabaababbbabababbababbaaabaabbabababababbababaaabaababbbbbbbbabbabbbbabbbabaababbbbabbaba | false | false | true
# bbbbabbbbababbbabbbabbbaabaaaaaabbabbabbbbabbbbabaabaaaabaaa | false | false | true
# ab                                  | true | true | true
# bbabbaba                            | true | true | true
# bbabbaabaababbabbbbabbbbaaabbbabbaababbaaabaaabbbabaababbbabbbaabbababbbbaabbbababbbbbababaaaaba | false | false | true
# bbabbaabab                          | true | true | true
# aaaabaaaabaabaababaaabaabbaaabaaaababbbababaababbabaabaabbbabaababbabbbbbabbbbbbababbbaababbbaababaaababbababaaababbabbaaabaabaaababbaabaabbbbaaaabababbbababbbbabbababaaaaaaabaaaabbbabbaaaabaaababbabbaaabbbbabb | true | true | true
# aaaabaaa                            | true | true | true
# abababbabbbbbbbabababababbabbbbbabbbaaaabaabaa | false | false | true
# aaabbabbabbabaaa                    | true | true | true
# aababababbaaabaabbabbbabbababbabbabbbabbbbabbaaabaabaaabaaabbbbbaaaabaabbabaaaabbbababaababa | true | true | true
# babababbabababbbababbabbbabbbbbaaababbabababaababaaaabaabaabbbbabbaaba | false | false | true
# aaba                                | true | true | true
# Совпадений: 50 из 50
